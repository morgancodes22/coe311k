# %% [markdown]
# # Eulers foward

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t,y):
    return (-1000*y + 3000 - 2000*np.exp(-t))

def exact(t):
    return (3 -.998*np.exp(-1000*t) - 2.002*np.exp(-t))

def Euler(y_not, step, start, stop):
    # setup
    num_steps = int(round((stop - start) / step))
    x = np.linspace(start, stop, num_steps + 1)
    y = np.zeros(num_steps + 1)

    # initial condition
    x[0] = start
    y[0] = y_not

    # go through each stepS
    for i in range(num_steps):
        x[i+1] = x[i] + step
        y[i+1] = y[i] + step * f(x[i], y[i])
    return x, y

h_vals = [.1, .01, .001, .00001, .0000001]

for j in range(len(h_vals)):
    h = h_vals[j]
    x, y = Euler(0, h, 0, 30)  # find approx
    plt.plot(x, y, label=f"h={h:.2f}")
    
x_exact = linspace(0,30,1000)
y_exact = exact(x_exact)
plt.plot(x_exact, y_exact, 'k--', label='Exact')
plt.show()
