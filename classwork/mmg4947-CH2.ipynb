# %% [markdown]
# # converting to binary

# %%
import numpy as np

x=2025 
bits=32


binary = np.zeros([32]) #hold all the values
i=bits-1 #increment

#calculate
while(x!=0):
    #print(x)
    #print("remainer",x%2) #debug
    
    binary[i]= x%2
    i=i-1
    x=x//2
    
#find signifcant figures
end = np.trim_zeros(binary, 'f') 
        
print(end)



""""
- i used ai to find a command to remove leading 0s on the array - i thought there might be a simple numpy command 
        to remove them instead of using loops to make it more efecient
- what i used: Claude
- what prompt: how to get rid of leading zeros in a numpy array? example: [0,0,0,0,0,1,1,0,1] -> [1,1,0,1]

""""""
# Out:
# [1. 1. 1. 1. 1. 1. 0. 1. 0. 0. 1.]
