# %% [markdown]
# # integer limit test

# %%
i=1
i=i+1
print(i)
# Out:
# 2

# %% [markdown]
# ### what happens when it reaches the max?

# %%
i= 2147483647
print(i)
# Out:
# 2147483647

# %%
i=i+1
print(i)
# Out:
# 2147483648

# %% [markdown]
# ### we get more memory when it reaches the max!
# this is only in Python 3 they get smart!

# %% [markdown]
# ### machine epsilon

# %%
1+2**2
# Out:
# 5

# %%
1+2**-50
# Out:
# 1.0000000000000009

# %%
1+2**-51
# Out:
# 1.0000000000000004

# %%
1+2**-52
# Out:
# 1.0000000000000002

# %%
1+2**-53
# Out:
# 1.0

# %% [markdown]
# The number go so small, it zeros out so this number should not be 1 becuase 1+2**-53 should be slightly greater than 1

# %% [markdown]
# machine epsilon is 2**-52 becuse it is the smallest value to add to 1 and not get 1!
